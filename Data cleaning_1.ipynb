# %%
import pandas as pd 


file_se = r''

data_se = pd.read_csv(file_se, sep='\t')

data_se
# Out:
#             SE
# 0         Abat
# 1        Abcf2
# 2       Abhd13
# 3         Abi1
# 4         Aco2
# ...        ...
# 6218     Haus2
# 6219      Nkd1
# 6220    Filip1
# 6221  Ppp1r14c
# 6222     Pygo1
#
# [6223 rows x 1 columns]

# %%
d6_syn_ac4cmrna = r''

d6_syn_ac4cmrna_control = pd.read_excel(d6_syn_ac4cmrna,sheet_name=0,header=0)

d6_syn_ac4cmrna_traininig = pd.read_excel(d6_syn_ac4cmrna,sheet_name=2,header=0)

d6_syn_ac4cmrna_control
# Out:
#                  gene_id     logFC    logCPM    PValue  FDR regulation  \
# 0     ENSMUSG00000031723  4.967987  3.320343  0.962032    1         up
# 1     ENSMUSG00000038718  4.235680  2.545778  0.810729    1         up
# 2     ENSMUSG00000059857  3.915428  1.434993  0.805420    1         up
# 3     ENSMUSG00000008475  3.689042  3.021691  0.929250    1         up
# 4     ENSMUSG00000025551  3.446741  2.398413  0.686175    1         up
# ...                  ...       ...       ...       ...  ...        ...
# 4663  ENSMUSG00000027304 -0.000967  6.304026  0.967211    1       down
# 4664  ENSMUSG00000062070 -0.000614  7.727230  0.971239    1       down
# 4665  ENSMUSG00000030126 -0.000603  7.011408  0.974477    1       down
# 4666  ENSMUSG00000027499 -0.000446  7.741689  0.964374    1       down
# 4667  ENSMUSG00000029474 -0.000386  5.767154  0.907404    1       down
#
#       Learned-syn.Input  Control-syn.Input  Learned-syn.Input.1  \
# ...

# %%
d6_syn_ac4cmrna_control  = d6_syn_ac4cmrna_control.drop_duplicates('gene_name',keep='first')

d6_syn_ac4cmrna_control
# Out:
#                  gene_id     logFC    logCPM    PValue  FDR regulation  \
# 0     ENSMUSG00000031723  4.967987  3.320343  0.962032    1         up
# 1     ENSMUSG00000038718  4.235680  2.545778  0.810729    1         up
# 2     ENSMUSG00000059857  3.915428  1.434993  0.805420    1         up
# 3     ENSMUSG00000008475  3.689042  3.021691  0.929250    1         up
# 4     ENSMUSG00000025551  3.446741  2.398413  0.686175    1         up
# ...                  ...       ...       ...       ...  ...        ...
# 4663  ENSMUSG00000027304 -0.000967  6.304026  0.967211    1       down
# 4664  ENSMUSG00000062070 -0.000614  7.727230  0.971239    1       down
# 4665  ENSMUSG00000030126 -0.000603  7.011408  0.974477    1       down
# 4666  ENSMUSG00000027499 -0.000446  7.741689  0.964374    1       down
# 4667  ENSMUSG00000029474 -0.000386  5.767154  0.907404    1       down
#
#       Learned-syn.Input  Control-syn.Input  Learned-syn.Input.1  \
# ...

# %%
d6_syn_ac4cmrna_traininig = d6_syn_ac4cmrna_traininig.drop_duplicates('gene_name',keep='first')

d6_syn_ac4cmrna_traininig
# Out:
#                  gene_id     logFC    logCPM    PValue  FDR regulation  \
# 0     ENSMUSG00000024862  5.321348  1.007287  0.920612    1         up
# 1     ENSMUSG00000039629  4.927747  2.163978  0.708542    1         up
# 2     ENSMUSG00000017664  4.927747  0.937980  0.755069    1         up
# 3     ENSMUSG00000025453  3.990383  2.240362  0.922617    1         up
# 4     ENSMUSG00000008976  3.937404  0.907390  0.786843    1         up
# ...                  ...       ...       ...       ...  ...        ...
# 4572  ENSMUSG00000027630 -0.001079  7.916385  0.969266    1       down
# 4573  ENSMUSG00000027304 -0.000967  6.304026  0.967211    1       down
# 4574  ENSMUSG00000062070 -0.000614  7.727230  0.971239    1       down
# 4575  ENSMUSG00000030126 -0.000603  7.011408  0.974477    1       down
# 4576  ENSMUSG00000027499 -0.000446  7.741689  0.964374    1       down
#
#       Learned-syn.Input  Control-syn.Input  Learned-syn.Input.1  \
# ...

# %%
d6_syn_ac4cpeak = r''

d6_syn_ac4cpeak_control = pd.read_excel(d6_syn_ac4cpeak,sheet_name=0,header=24)

d6_syn_ac4cpeak_traininig = pd.read_excel(d6_syn_ac4cpeak,sheet_name=1,header=24)

d6_syn_ac4cpeak_control
# Out:
#       chrom   txStart     txEnd           PeakID    score strand  Peak_length  \
# 0      chr4  62322190  62322277  MACS_peak_48091    43.17      -           87
# 1      chr4  62323196  62323274  MACS_peak_48092    57.40      -           78
# 2      chr4  62388707  62388915  MACS_peak_48097  2285.12      +          208
# 3      chr4  62462140  62462215  MACS_peak_48102    52.48      -           75
# 4      chr4  62509194  62509310  MACS_peak_48104   184.21      -          116
# ...     ...       ...       ...              ...      ...    ...          ...
# 23130  chr4  59903727  59903931  MACS_peak_48071  2031.56      +          204
# 23131  chr4  62204532  62204650  MACS_peak_48084   187.74      -          118
# 23132  chr4  62286564  62286574  MACS_peak_48086   755.79      +           10
# 23133  chr4  62296010  62296076  MACS_peak_48088   809.55      +           66
# 23134  chr4  62296974  62297152  MACS_peak_48089   857.26      +          178
#
# ...

# %%
d6_syn_ac4cpeak_traininig
# Out:
#        chrom   txStart     txEnd           PeakID    score strand  \
# 0      chr12  36022770  36022833  MACS_peak_16230   452.14      -
# 1      chr12  36023904  36024072  MACS_peak_16231   520.51      -
# 2      chr12  37880180  37880418  MACS_peak_16261   906.73      +
# 3      chr12  38827777  38827907  MACS_peak_16312  1009.12      +
# 4      chr12  38831080  38831269  MACS_peak_16313   967.99      +
# ...      ...       ...       ...              ...      ...    ...
# 21533  chr12  34390141  34390171  MACS_peak_16193   342.35      -
# 21534  chr12  35103120  35103140  MACS_peak_16222    80.66      +
# 21535  chr12  35145499  35145718  MACS_peak_16226  3100.00      +
# 21536  chr12  35534855  35535038  MACS_peak_16228   551.21      -
# 21537  chr12  36021800  36021914  MACS_peak_16229   245.65      -
#
#        Peak_length       transcript_id GeneName  c10_log10_pvalue  ...    FDR  \
# 0               63           NM_025359  Tspan13            452.14  ...  16.32
# ...

# %%
d6_mrna中的peak_syn_control_isin = d6_syn_ac4cpeak_control[d6_syn_ac4cpeak_control['GeneName'].isin(d6_syn_ac4cmrna_control['gene_name'])]

d6_mrna中的peak_syn_control_isin
# Out:
#       chrom   txStart     txEnd           PeakID    score strand  Peak_length  \
# 0      chr4  62322190  62322277  MACS_peak_48091    43.17      -           87
# 1      chr4  62323196  62323274  MACS_peak_48092    57.40      -           78
# 2      chr4  62388707  62388915  MACS_peak_48097  2285.12      +          208
# 23     chr4  65613185  65613862  MACS_peak_48146  2528.75      +          677
# 24     chr4  65614098  65614584  MACS_peak_48147    78.86      +          486
# ...     ...       ...       ...              ...      ...    ...          ...
# 23111  chr4  58437098  58437634  MACS_peak_48026   100.17      -          536
# 23112  chr4  58487141  58487224  MACS_peak_48027   465.16      -           83
# 23113  chr4  58504621  58504858  MACS_peak_48028   786.05      -          237
# 23114  chr4  58553133  58553291  MACS_peak_48029   453.16      -          158
# 23131  chr4  62204532  62204650  MACS_peak_48084   187.74      -          118
#
# ...

# %%
d6_mrna中的peak_syn_traininig_isin = d6_syn_ac4cpeak_traininig[d6_syn_ac4cpeak_traininig['GeneName'].isin(d6_syn_ac4cmrna_traininig['gene_name'])]

d6_mrna中的peak_syn_traininig_isin
# Out:
#        chrom   txStart     txEnd           PeakID    score strand  \
# 0      chr12  36022770  36022833  MACS_peak_16230   452.14      -
# 1      chr12  36023904  36024072  MACS_peak_16231   520.51      -
# 2      chr12  37880180  37880418  MACS_peak_16261   906.73      +
# 3      chr12  38827777  38827907  MACS_peak_16312  1009.12      +
# 4      chr12  38831080  38831269  MACS_peak_16313   967.99      +
# ...      ...       ...       ...              ...      ...    ...
# 21530  chr12  33371989  33372235  MACS_peak_16183  2971.91      +
# 21531  chr12  33373775  33374043  MACS_peak_16184   611.48      +
# 21534  chr12  35103120  35103140  MACS_peak_16222    80.66      +
# 21535  chr12  35145499  35145718  MACS_peak_16226  3100.00      +
# 21537  chr12  36021800  36021914  MACS_peak_16229   245.65      -
#
#        Peak_length       transcript_id GeneName  c10_log10_pvalue  ...    FDR  \
# 0               63           NM_025359  Tspan13            452.14  ...  16.32
# ...

# %%
d6_mrna中的peak_syn_control_isin_3utr = d6_mrna中的peak_syn_control_isin[d6_mrna中的peak_syn_control_isin['Catalog']=='3UTR']

d6_mrna中的peak_syn_control_isin_3utr_group = d6_mrna中的peak_syn_control_isin_3utr.groupby('GeneName').sum()

d6_mrna中的peak_syn_control_isin_3utr_group
# Out:
#                     chrom    txStart      txEnd  \
# GeneName
# 1700025G04Rik        chr1  151885364  151885840
# 1700066M21Rik        chr1   57383924   57384192
# 2310022B05Rik        chr8  124636012  124637234
# 2510009E07Rik       chr16   21651284   21651495
# 2610002M06Rik        chrX  107786307  107786525
# ...                   ...        ...        ...
# Zmiz1          chr14chr14   51330444   51330955
# Zswim5               chr4  116988981  116989264
# Zyg11b               chr4  108231178  108231402
# Zyx                  chr6   42358966   42359183
# Zzz3                 chr3  152461578  152461799
#
#                                        PeakID    score strand  Peak_length  \
# GeneName
# 1700025G04Rik                  MACS_peak_3485   256.39      -          476
# 1700066M21Rik                  MACS_peak_1361  1444.26      +          268
# 2310022B05Rik                 MACS_peak_70125   565.08      -         1222
# ...

# %%
d6_mrna中的peak_syn_control_isin_5utr = d6_mrna中的peak_syn_control_isin[d6_mrna中的peak_syn_control_isin['Catalog']=='5UTR']

d6_mrna中的peak_syn_control_isin_5utr_group = d6_mrna中的peak_syn_control_isin_5utr.groupby('GeneName').sum()

d6_mrna中的peak_syn_control_isin_5utr_group
# Out:
#                chrom    txStart      txEnd                        PeakID  \
# GeneName
# Abat           chr16    8513462    8513574               MACS_peak_26565
# Abca3          chr17   24352087   24352251               MACS_peak_30163
# Abca5          chr11  110337484  110337695               MACS_peak_13244
# Abcg4           chr9   44288119   44288359               MACS_peak_71691
# Abr            chr11   76494719   76494978               MACS_peak_11424
# ...              ...        ...        ...                           ...
# Zmiz2     chr11chr11   12784487   12784801  MACS_peak_8985MACS_peak_8986
# Zmynd11        chr13    9764727    9764956               MACS_peak_17062
# Zmynd8          chr2  165876359  165876605               MACS_peak_42380
# Znfx1           chr2  167062509  167062754               MACS_peak_42448
# Zzz3            chr3  152396709  152396761               MACS_peak_46435
#
#             score strand  Peak_length        transcript_id  -10*log10(pvalue)  \
# ...

# %%
d6_mrna中的peak_syn_control_isin_cds = d6_mrna中的peak_syn_control_isin[(d6_mrna中的peak_syn_control_isin['Catalog'] != '5UTR')&(d6_mrna中的peak_syn_control_isin['Catalog'] != '3UTR')]

d6_mrna中的peak_syn_control_isin_cds_group = d6_mrna中的peak_syn_control_isin_cds.groupby('GeneName').sum()

d6_mrna中的peak_syn_control_isin_cds_group
# Out:
#                                    chrom    txStart      txEnd  \
# GeneName
# 1110004F10Rik                       chr7  116101988  116102004
# 1500009C09Rik                      chr15   82259573   82260683
# 1500011B03Rik                       chr5  114813779  114813916
# 1700003E16Rik                       chr6   83161845   83162518
# 1700025G04Rik           chr1chr1chr1chr1  607710378  607710585
# ...                                  ...        ...        ...
# Zrsr1                         chr11chr11   45947469   45948826
# Zrsr2                       chrXchrXchrX  491864422  491864691
# Zwint                              chr10   72654894   72654977
# Zzef1          chr11chr11chr11chr11chr11  364381516  364382456
# Zzz3                            chr3chr3  304878125  304878901
#
#                                                           PeakID    score  \
# GeneName
# 1110004F10Rik                                    MACS_peak_65097   847.42
# ...

# %%
d6_mrna中的peak_syn_traininig_isin_3utr = d6_mrna中的peak_syn_traininig_isin[d6_mrna中的peak_syn_traininig_isin['Catalog']=='3UTR']

d6_mrna中的peak_syn_traininig_isin_3utr_group = d6_mrna中的peak_syn_traininig_isin_3utr.groupby('GeneName').sum()

d6_mrna中的peak_syn_traininig_isin_3utr_group
# Out:
#                           chrom    txStart      txEnd  \
# GeneName
# 1700025G04Rik              chr1  151891384  151892007
# 2900026A02Rik  chr5chr5chr5chr5  452353741  452354819
# 5730409E04Rik              chr4  126613075  126613627
# 5730455P16Rik             chr11   80362938   80363216
# Aagab                  chr9chr9  127282595  127283357
# ...                         ...        ...        ...
# Zmiz1                     chr14   25664480   25664807
# Zmiz2                     chr11    6405881    6406162
# Zmym2                     chr14   56960518   56960734
# Zswim6                    chr13  107725083  107725620
# Zzef1                     chr11   72926235   72926667
#
#                                                           PeakID    score  \
# GeneName
# 1700025G04Rik                                     MACS_peak_4020   170.99
# 2900026A02Rik  MACS_peak_61239MACS_peak_61240MACS_peak_61241M...  5195.35
# ...

# %%
d6_mrna中的peak_syn_traininig_isin_5utr = d6_mrna中的peak_syn_traininig_isin[d6_mrna中的peak_syn_traininig_isin['Catalog']=='5UTR']

d6_mrna中的peak_syn_traininig_isin_5utr_group = d6_mrna中的peak_syn_traininig_isin_5utr.groupby('GeneName').sum()

d6_mrna中的peak_syn_traininig_isin_5utr_group
# Out:
#                     chrom    txStart      txEnd  \
# GeneName
# 1700025G04Rik        chr1  152089931  152090320
# Abat                chr16    8513479    8513574
# Abca3               chr17   24360887   24361089
# Abca5               chr11  110337484  110337701
# Abcc5               chr16   20426247   20426257
# ...                   ...        ...        ...
# Zhx3                 chr2  160872429  160872493
# Zmiz1               chr14   25459184   25459556
# Zmiz2          chr11chr11   12784487   12784801
# Zmynd11             chr13    9765057    9765257
# Znfx1                chr2  167062509  167062809
#
#                                        PeakID    score strand  Peak_length  \
# GeneName
# 1700025G04Rik                  MACS_peak_4033   679.57      -          389
# Abat                          MACS_peak_29728  1504.98      +           95
# Abca3                         MACS_peak_33861  1025.00      +          202
# ...

# %%
d6_mrna中的peak_syn_traininig_isin_cds = d6_mrna中的peak_syn_traininig_isin[(d6_mrna中的peak_syn_traininig_isin['Catalog'] != '5UTR')&(d6_mrna中的peak_syn_traininig_isin['Catalog'] != '3UTR')]

d6_mrna中的peak_syn_traininig_isin_cds_group = d6_mrna中的peak_syn_traininig_isin_cds.groupby('GeneName').sum()

d6_mrna中的peak_syn_traininig_isin_cds_group
# Out:
#                                    chrom    txStart      txEnd  \
# GeneName
# 1110004F10Rik                       chr7  116103236  116103320
# 1500009C09Rik                      chr15   82259564   82260624
# 2210016L21Rik                   chr5chr5  229889912  229890146
# 2310022B05Rik               chr8chr8chr8  373953343  373954278
# 2610507B11Rik                 chr11chr11  156537775  156538037
# ...                                  ...        ...        ...
# Zswim6                             chr13  107889636  107889901
# Zwint                              chr10   72654900   72654977
# Zyg11b                          chr4chr4  216495369  216495506
# Zzef1          chr11chr11chr11chr11chr11  364170381  364171165
# Zzz3                            chr3chr3  304909643  304910104
#
#                                                           PeakID     score  \
# GeneName
# 1110004F10Rik                                    MACS_peak_72601    337.34
# ...

# %%
d6_mrnahompeak = r''

d6_mrna中的peak_hom_control_3utr = pd.read_excel(d6_mrnahompeak,sheet_name=0,header=0)

d6_mrna中的peak_hom_control_5utr = pd.read_excel(d6_mrnahompeak,sheet_name=1,header=0)

d6_mrna中的peak_hom_control_cds = pd.read_excel(d6_mrnahompeak,sheet_name=2,header=0)

d6_mrna中的peak_hom_traininig_3utr = pd.read_excel(d6_mrnahompeak,sheet_name=3,header=0)

d6_mrna中的peak_hom_traininig_5utr = pd.read_excel(d6_mrnahompeak,sheet_name=4,header=0)

d6_mrna中的peak_hom_traininig_cds = pd.read_excel(d6_mrnahompeak,sheet_name=5,header=0)

d6_mrna中的peak_hom_control_3utr
# Out:
#      chrom    txStart      txEnd                     PeakID    score strand  \
# 0    chr11   97756260   97756684  Control-1_MACS_peak_13922    82.14      -
# 1    chr19    6829084    6829738  Control-1_MACS_peak_39726   151.79      -
# 2     chr2   29844789   29845002  Control-1_MACS_peak_42998  3100.00      +
# 3     chr6  126708328  126708707  Control-1_MACS_peak_70226  1267.57      -
# 4     chrX   21026851   21028048  Control-2_MACS_peak_75204    98.41      -
# ..     ...        ...        ...                        ...      ...    ...
# 142  chr11   55446640   55446784  Control-1_MACS_peak_11076    55.56      -
# 143   chr4  148078021  148079770  Control-1_MACS_peak_58065   295.89      -
# 144   chr4  108015309  108015695  Control-1_MACS_peak_54898    97.68      -
# 145   chrX   71153873   71155975  Control-1_MACS_peak_88212  2872.54      +
# 146  chr17   47685236   47686738  Control-2_MACS_peak_30554   530.06      +
#
# ...

# %%
d6_mrna中的peak_hom_control_5utr
# Out:
#       chrom    txStart      txEnd                     PeakID    score strand  \
# 0     chr19   46327083   46327156  Control-1_MACS_peak_41176    62.65      -
# 1      chr5  134552045  134552434  Control-1_MACS_peak_64915  1592.15      -
# 2     chr14    8080320    8080512  Control-1_MACS_peak_22689    46.23      +
# 3      chr2  181287883  181288035  Control-2_MACS_peak_42472   385.38      -
# 4     chr17   25941814   25942048  Control-1_MACS_peak_33656   313.87      -
# ...     ...        ...        ...                        ...      ...    ...
# 1682  chr15   13173513   13173639  Control-2_MACS_peak_22776   126.56      -
# 1683   chr1  163929764  163930186   Control-1_MACS_peak_4116    56.03      +
# 1684  chr14   58075114   58075366  Control-2_MACS_peak_21177    86.16      +
# 1685  chr14   59201227   59201584  Control-1_MACS_peak_24287   166.49      +
# 1686   chr4  147903354  147903497  Control-1_MACS_peak_58032   195.77      -
#
# ...

# %%
d6_mrna中的peak_hom_control_cds
# Out:
#        chrom   txStart     txEnd                     PeakID   score strand  \
# 0      chr11   5871244   5872248   Control-1_MACS_peak_9754  149.01      +
# 1      chr11   5803274   5803796   Control-1_MACS_peak_9747  358.92      -
# 2      chr11   5827859   5829115   Control-1_MACS_peak_9748  379.76      -
# 3      chr19  46367708  46368161  Control-1_MACS_peak_41187  191.94      +
# 4      chr19  46396895  46397284  Control-1_MACS_peak_41196  141.41      +
# ...      ...       ...       ...                        ...     ...    ...
# 10326  chr15  95640638  95640734  Control-2_MACS_peak_25230  127.49      -
# 10327  chr15  96369919  96372762  Control-1_MACS_peak_28893  156.14      +
# 10328  chr15  58945316  58945524  Control-1_MACS_peak_26836  101.61      -
# 10329  chr10  79685232  79685367   Control-1_MACS_peak_7658   68.23      +
# 10330  chr15  58951469  58951680  Control-1_MACS_peak_26839  156.57      -
#
# ...

# %%
d6_mrna中的peak_hom_traininig_cds
# Out:
#       chrom    txStart      txEnd                      PeakID    score strand  \
# 0      chr5  110205776  110205871  Training-1_MACS_peak_81764   121.32      +
# 1     chr11   82764344   82765689  Training-1_MACS_peak_17394   153.13      +
# 2      chr5  110201830  110201992  Training-1_MACS_peak_81760   463.89      +
# 3      chr3  108017739  108017973  Training-1_MACS_peak_67975  2740.39      -
# 4      chr7   19282623   19282865  Training-1_MACS_peak_93441    96.36      +
# ...     ...        ...        ...                         ...      ...    ...
# 9661   chr5   31192581   31193139  Training-1_MACS_peak_78669  2281.47      -
# 9662   chr4   85355326   85355399  Training-2_MACS_peak_49989    42.54      +
# 9663   chr4   84884308   84884824  Training-2_MACS_peak_49971    62.48      +
# 9664   chr7  130716702  130716839  Training-1_MACS_peak_99947   263.47      +
# 9665   chr4   85376340   85376484  Training-2_MACS_peak_49992   521.27      +
#
# ...

# %%
d6_mrna中的peak_hom_control_3utr_group = d6_mrna中的peak_hom_control_3utr.groupby('GeneName').sum()

d6_mrna中的peak_hom_control_5utr_group = d6_mrna中的peak_hom_control_5utr.groupby('GeneName').sum()

d6_mrna中的peak_hom_control_cds_group = d6_mrna中的peak_hom_control_cds.groupby('GeneName').sum()

d6_mrna中的peak_hom_traininig_3utr_group = d6_mrna中的peak_hom_traininig_3utr.groupby('GeneName').sum()

d6_mrna中的peak_hom_traininig_5utr_group = d6_mrna中的peak_hom_traininig_5utr.groupby('GeneName').sum()

d6_mrna中的peak_hom_training_cds_group = d6_mrna中的peak_hom_traininig_cds.groupby('GeneName').sum()

d6_mrna中的peak_hom_training_cds_group
# Out:
#                          chrom    txStart      txEnd  \
# GeneName
# 0610010K14Rik            chr11   70237783   70238470
# 1110001J03Rik             chr6   38539158   38539449
# 1110004E09Rik       chr16chr16  181860908  181861144
# 1110004F10Rik     chr7chr7chr7  348294682  348295052
# 1110008F13Rik             chr2  156863121  156863417
# ...                        ...        ...        ...
# Zswim6                   chr13  107787652  107788009
# Zswim8                   chr14   20707551   20708056
# Zw10                      chr9   49055580   49055787
# Zyx                       chr6   42357851   42358562
# Zzef1          chr11chr11chr11  218540011  218540688
#
#                                                           PeakID    score  \
# GeneName
# 0610010K14Rik                         Training-1_MACS_peak_15924   135.70
# 1110001J03Rik                         Training-1_MACS_peak_87858    59.15
# 1110004E09Rik  Training-1_MACS_peak_42924Training-1_MACS_peak...  2742.80
# ...

# %%
d1d20peak = r''

d1_mrna中的peak_syn_c1_3utr = pd.read_excel(d1d20peak,sheet_name=4,header=0)

d1_mrna中的peak_syn_c1_5utr = pd.read_excel(d1d20peak,sheet_name=5,header=0)

d1_mrna中的peak_syn_c1_cds = pd.read_excel(d1d20peak,sheet_name=6,header=0)

d1_mrna中的peak_syn_t1_3utr = pd.read_excel(d1d20peak,sheet_name=7,header=0)

d1_mrna中的peak_syn_t1_5utr = pd.read_excel(d1d20peak,sheet_name=8,header=0)

d1_mrna中的peak_syn_t1_cds = pd.read_excel(d1d20peak,sheet_name=9,header=0)

d20_mrna中的peak_syn_c1_3utr = pd.read_excel(d1d20peak,sheet_name=10,header=0)

d20_mrna中的peak_syn_c1_5utr = pd.read_excel(d1d20peak,sheet_name=11,header=0)

d20_mrna中的peak_syn_c1_cds = pd.read_excel(d1d20peak,sheet_name=12,header=0)

d20_mrna中的peak_syn_t1_3utr = pd.read_excel(d1d20peak,sheet_name=13,header=0)

d20_mrna中的peak_syn_t1_5utr = pd.read_excel(d1d20peak,sheet_name=14,header=0)

d20_mrna中的peak_syn_t1_cds = pd.read_excel(d1d20peak,sheet_name=15,header=0)

d1_mrna中的peak_syn_c1_3utr
# Out:
#     chrom    txStart      txEnd            PeakID   score strand  Peak_length  \
# 0    chr2  121561384  121561532  MACS_peak_129648   88.87      -          148
# 1    chr3  103633467  103633675  MACS_peak_144633  135.74      +          208
# 2    chr3  126818371  126818599  MACS_peak_146600  281.33      +          228
# 3    chr3   86619861   86620120  MACS_peak_142801  165.26      +          259
# 4    chr3   55128067   55128788  MACS_peak_140174  130.38      +          721
# ..    ...        ...        ...               ...     ...    ...          ...
# 541  chr3   38451635   38451953  MACS_peak_138983  291.55      -          318
# 542  chr3   52347045   52347659  MACS_peak_139908   81.93      +          614
# 543  chr3   75901054   75901314  MACS_peak_141994  308.42      -          260
# 544  chr3   96868280   96869345  MACS_peak_144042   54.15      -         1065
# 545  chr2   71271097   71271334  MACS_peak_125123   65.67      -          237
#
# ...

# %%
d20_mrna中的peak_syn_t1_cds
# Out:
#       chrom   txStart     txEnd           PeakID   score strand  Peak_length  \
# 0     chr15  77764299  77764423  MACS_peak_83893  577.14      -          124
# 1     chr15  77777767  77777928  MACS_peak_83902   79.63      -          161
# 2     chr15  77779989  77780059  MACS_peak_83904  204.81      -           70
# 3     chr15  79763509  79763593  MACS_peak_84275   89.39      -           84
# 4     chr15  80348371  80348531  MACS_peak_84371  532.72      +          160
# ...     ...       ...       ...              ...     ...    ...          ...
# 7009  chr15  72685282  72685373  MACS_peak_83151   40.78      -           91
# 7010  chr15  72903556  72903681  MACS_peak_83185   41.64      -          125
# 7011  chr15  73031548  73031643  MACS_peak_83197   58.90      -           95
# 7012  chr15  73295352  73295375  MACS_peak_83255   68.22      -           23
# 7013  chr15  76331230  76331266  MACS_peak_83632  113.54      +           36
#
# ...

# %%
d1_mrna中的peak_syn_c1_3utr_group = d1_mrna中的peak_syn_c1_3utr.groupby('GeneName').sum()

d1_mrna中的peak_syn_c1_5utr_group = d1_mrna中的peak_syn_c1_5utr.groupby('GeneName').sum()

d1_mrna中的peak_syn_c1_cds_group = d1_mrna中的peak_syn_c1_cds.groupby('GeneName').sum()

d1_mrna中的peak_syn_t1_3utr_group = d1_mrna中的peak_syn_t1_3utr.groupby('GeneName').sum()

d1_mrna中的peak_syn_t1_5utr_group = d1_mrna中的peak_syn_t1_5utr.groupby('GeneName').sum()

d1_mrna中的peak_syn_t1_cds_group = d1_mrna中的peak_syn_t1_cds.groupby('GeneName').sum()

d20_mrna中的peak_syn_c1_3utr_group = d20_mrna中的peak_syn_c1_3utr.groupby('GeneName').sum()

d20_mrna中的peak_syn_c1_5utr_group = d20_mrna中的peak_syn_c1_5utr.groupby('GeneName').sum()

d20_mrna中的peak_syn_c1_cds_group = d20_mrna中的peak_syn_c1_cds.groupby('GeneName').sum()

d20_mrna中的peak_syn_t1_3utr_group = d20_mrna中的peak_syn_t1_3utr.groupby('GeneName').sum()

d20_mrna中的peak_syn_t1_5utr_group = d20_mrna中的peak_syn_t1_5utr.groupby('GeneName').sum()

d20_mrna中的peak_syn_t1_cds_group = d20_mrna中的peak_syn_t1_cds.groupby('GeneName').sum()

d20_mrna中的peak_syn_t1_cds_group
# Out:
#                                    chrom    txStart      txEnd  \
# GeneName
# 1500011B03Rik                       chr5  114813779  114813847
# 1700025G04Rik                       chr1  152006544  152006767
# 2510009E07Rik                      chr16   21694215   21694600
# 2610301B20Rik                       chr4   10898105   10898362
# 2610507B11Rik                      chr11   78269487   78269693
# ...                                  ...        ...        ...
# Zswim5                      chr4chr4chr4  350849948  350850674
# Zswim6                             chr13  107738434  107738632
# Zyg11b                              chr4  108300890  108301096
# Zyx                                 chr6   42350256   42350476
# Zzef1          chr11chr11chr11chr11chr11  364200654  364201311
#
#                                                           PeakID   score  \
# GeneName
# 1500011B03Rik                                   MACS_peak_180437  113.99
# ...

# %%
writer = pd.ExcelWriter(r'')

d1_mrna中的peak_syn_c1_3utr_group.to_excel(writer,sheet_name='d1_mrna中peak_syn_c1_3utr',index=True)
d1_mrna中的peak_syn_c1_5utr_group.to_excel(writer,sheet_name='d1_mrna中peak_syn_c1_5utr',index=True)
d1_mrna中的peak_syn_c1_cds_group.to_excel(writer,sheet_name='d1_mrna中peak_syn_c1_cds',index=True)
d1_mrna中的peak_syn_t1_3utr_group.to_excel(writer,sheet_name='d1_mrna中peak_syn_t1_3utr',index=True)
d1_mrna中的peak_syn_t1_5utr_group.to_excel(writer,sheet_name='d1_mrna中peak_syn_t1_5utr',index=True)
d1_mrna中的peak_syn_t1_cds_group.to_excel(writer,sheet_name='d1_mrna中peak_syn_t1_cds',index=True)



d6_mrna中的peak_hom_control_3utr_group.to_excel(writer,sheet_name='d6_mrna中peak_hom_control_3utr',index=True)
d6_mrna中的peak_hom_control_5utr_group.to_excel(writer,sheet_name='d6_mrna中peak_hom_control_5utr',index=True)
d6_mrna中的peak_hom_control_cds_group.to_excel(writer,sheet_name='d6_mrna中peak_hom_control_cds',index=True)
d6_mrna中的peak_hom_traininig_3utr_group.to_excel(writer,sheet_name='d6_mrna中peak_hom_training_3utr',index=True)
d6_mrna中的peak_hom_traininig_5utr_group.to_excel(writer,sheet_name='d6_mrna中peak_hom_training_5utr',index=True)
d6_mrna中的peak_hom_training_cds_group.to_excel(writer,sheet_name='d6_mrna中peak_hom_training_cds',index=True)

d6_mrna中的peak_syn_control_isin_3utr_group.to_excel(writer,sheet_name='d6_mrna中peak_syn_control_3utr',index=True)
d6_mrna中的peak_syn_control_isin_5utr_group.to_excel(writer,sheet_name='d6_mrna中peak_syn_control_5utr',index=True)
d6_mrna中的peak_syn_control_isin_cds_group.to_excel(writer,sheet_name='d6_mrna中peak_syn_control_cds',index=True)
d6_mrna中的peak_syn_traininig_isin_3utr_group.to_excel(writer,sheet_name='d6_mrna中peak_syn_traininig_3utr',index=True)
d6_mrna中的peak_syn_traininig_isin_5utr_group.to_excel(writer,sheet_name='d6_mrna中peak_syn_traininig_5utr',index=True)
d6_mrna中的peak_syn_traininig_isin_cds_group.to_excel(writer,sheet_name='d6_mrna中peak_syn_traininig_cds',index=True)



d20_mrna中的peak_syn_c1_3utr_group.to_excel(writer,sheet_name='d20_mrna中peak_syn_c20_3utr',index=True)
d20_mrna中的peak_syn_c1_5utr_group.to_excel(writer,sheet_name='d20_mrna中peak_syn_c20_5utr',index=True)
d20_mrna中的peak_syn_c1_cds_group.to_excel(writer,sheet_name='d20_mrna中peak_syn_c20_cds',index=True)
d20_mrna中的peak_syn_t1_3utr_group.to_excel(writer,sheet_name='d20_mrna中peak_syn_t20_3utr',index=True)
d20_mrna中的peak_syn_t1_5utr_group.to_excel(writer,sheet_name='d20_mrna中peak_syn_t20_5utr',index=True)
d20_mrna中的peak_syn_t1_cds_group.to_excel(writer,sheet_name='d20_mrna中peak_syn_t20_cds',index=True)

writer.close()
