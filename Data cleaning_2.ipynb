# %%
import pandas as pd 


file_se = r''

data_se = pd.read_csv(file_se, sep='\t')

data_se
# Out:
#             SE
# 0         Abat
# 1        Abcf2
# 2       Abhd13
# 3         Abi1
# 4         Aco2
# ...        ...
# 6218     Haus2
# 6219      Nkd1
# 6220    Filip1
# 6221  Ppp1r14c
# 6222     Pygo1
#
# [6223 rows x 1 columns]

# %%
d1d20 = r''

d1_up = pd.read_excel(d1d20,sheet_name=0,header=14)

d1_down = pd.read_excel(d1d20,sheet_name=1,header=14)

d20_up = pd.read_excel(d1d20,sheet_name=2,header=14)

d20_down = pd.read_excel(d1d20,sheet_name=3,header=14)

d1_up
# Out:
#        chrom      start        end                   PeakID   score strand  \
# 0      chr18   77796274   77796582  Syn-T1_MACS_peak_125699  574.44      +
# 1       chr4  132227871  132227994  Syn-T1_MACS_peak_182503  113.23      -
# 2       chr4  140702146  140702435  Syn-T1_MACS_peak_183771  299.00      +
# 3       chr4  141037847  141038030  Syn-T1_MACS_peak_183822   96.73      -
# 4       chr4  146198070  146198315  Syn-T1_MACS_peak_184565   53.89      +
# ...      ...        ...        ...                      ...     ...    ...
# 12575  chr18   32264623   32264665  Syn-T1_MACS_peak_120698   48.50      +
# 12576  chr18   34334521   34334568  Syn-T1_MACS_peak_120890   51.40      +
# 12577  chr18   35696977   35697123  Syn-T1_MACS_peak_121060   86.57      -
# 12578  chr18   36365780   36365878  Syn-T1_MACS_peak_121172   83.68      +
# 12579  chr18   37323132   37323621  Syn-T1_MACS_peak_121330  103.32      +
#
# ...

# %%
d20_down
# Out:
#        chrom     start       end                   PeakID   score strand  \
# 0      chr15  77777767  77777928  Syn-T20_MACS_peak_83902   79.63      -
# 1      chr15  77779989  77780059  Syn-T20_MACS_peak_83904  204.81      -
# 2      chr15  80251721  80251971  Syn-T20_MACS_peak_84347   85.84      +
# 3      chr15  81388329  81388400  Syn-T20_MACS_peak_84528   83.57      -
# 4      chr15  83388514  83388670  Syn-T20_MACS_peak_84862   50.76      -
# ...      ...       ...       ...                      ...     ...    ...
# 17008  chr12  76095499  76095674  Syn-C20_MACS_peak_39266  944.94      +
# 17009  chr12  78845225  78845304  Syn-C20_MACS_peak_39526  105.64      -
# 17010  chr12  81026807  81027035  Syn-C20_MACS_peak_39742  203.83      +
# 17011  chr12  81496126  81496347  Syn-C20_MACS_peak_39802  323.94      -
# 17012  chr12  84009501  84009853  Syn-C20_MACS_peak_40093   78.23      +
#
#        log2FoldChange Regulation  Syn-T20  Syn-C20  ... GeneName    GeneID  \
# ...

# %%
d6 = r''

d6_up = pd.read_excel(d6,sheet_name=0,header=14)

d6_down = pd.read_excel(d6,sheet_name=1,header=14)

d6_up
# Out:
#        chrom       start         end                       PeakID    score  \
# 0      chr12  36023904.0  36024072.0  Learned-syn_MACS_peak_16231   520.51
# 1      chr12  38827777.0  38827907.0  Learned-syn_MACS_peak_16312  1009.12
# 2      chr12  40810444.0  40810521.0  Learned-syn_MACS_peak_16365  1816.48
# 3      chr12  49384294.0  49385641.0  Learned-syn_MACS_peak_16490  3100.00
# 4      chr12  51691421.0  51691914.0  Learned-syn_MACS_peak_16530  2263.87
# ...      ...         ...         ...                          ...      ...
# 38186    NaN         NaN         NaN                          NaN      NaN
# 38187    NaN         NaN         NaN                          NaN      NaN
# 38188    NaN         NaN         NaN                          NaN      NaN
# 38189    NaN         NaN         NaN                          NaN      NaN
# 38190    NaN         NaN         NaN                          NaN      NaN
#
# ...

# %%
d6_down
# Out:
#        chrom     start       end                        PeakID    score  \
# 0      chr12  38831080  38831269   Learned-syn_MACS_peak_16313   967.99
# 1      chr12  40844239  40844586   Learned-syn_MACS_peak_16371    57.08
# 2      chr12  44290642  44290660   Learned-syn_MACS_peak_16408   357.26
# 3      chr12  51647993  51648135   Learned-syn_MACS_peak_16526   427.10
# 4      chr12  51829202  51829305   Learned-syn_MACS_peak_16545   143.17
# ...      ...       ...       ...                           ...      ...
# 19461   chr4  59423994  59424116  Control-syn1_MACS_peak_48058  2869.72
# 19462   chr4  59892461  59892506  Control-syn1_MACS_peak_48070  3100.00
# 19463   chr4  62204532  62204650  Control-syn1_MACS_peak_48084   187.74
# 19464   chr4  62286564  62286574  Control-syn1_MACS_peak_48086   755.79
# 19465   chr4  62296010  62296076  Control-syn1_MACS_peak_48088   809.55
#
#       strand  log2FoldChange Regulation  Learned-syn  Control-syn1  ...  \
# ...

# %%
d1_up_isinse = d1_up[d1_up['GeneName'].isin(data_se['SE'])]

d1_down_isinse = d1_down[d1_down['GeneName'].isin(data_se['SE'])]

d6_up_isinse = d6_up[d6_up['GeneName'].isin(data_se['SE'])]

d6_down_isinse = d6_down[d6_down['GeneName'].isin(data_se['SE'])]

d20_up_isinse = d20_up[d20_up['GeneName'].isin(data_se['SE'])]

d20_down_isinse = d20_down[d20_down['GeneName'].isin(data_se['SE'])]

d20_down_isinse
# Out:
#        chrom     start       end                   PeakID   score strand  \
# 0      chr15  77777767  77777928  Syn-T20_MACS_peak_83902   79.63      -
# 1      chr15  77779989  77780059  Syn-T20_MACS_peak_83904  204.81      -
# 3      chr15  81388329  81388400  Syn-T20_MACS_peak_84528   83.57      -
# 4      chr15  83388514  83388670  Syn-T20_MACS_peak_84862   50.76      -
# 5      chr15  83610153  83610351  Syn-T20_MACS_peak_84889  102.85      -
# ...      ...       ...       ...                      ...     ...    ...
# 17004  chr12  73941960  73942314  Syn-C20_MACS_peak_39124   54.03      +
# 17005  chr12  74238180  74238370  Syn-C20_MACS_peak_39171   64.70      +
# 17009  chr12  78845225  78845304  Syn-C20_MACS_peak_39526  105.64      -
# 17010  chr12  81026807  81027035  Syn-C20_MACS_peak_39742  203.83      +
# 17011  chr12  81496126  81496347  Syn-C20_MACS_peak_39802  323.94      -
#
#        log2FoldChange Regulation  Syn-T20  Syn-C20  ... GeneName    GeneID  \
# ...

# %%
d1_up_isinse
# Out:
#        chrom      start        end                   PeakID   score strand  \
# 2       chr4  140702146  140702435  Syn-T1_MACS_peak_183771  299.00      +
# 5      chr17   74338986   74339445  Syn-T1_MACS_peak_115699  197.66      +
# 6      chr17   80205847   80206028  Syn-T1_MACS_peak_116219  102.56      -
# 7      chr18   30277050   30277115  Syn-T1_MACS_peak_120465  230.02      +
# 8      chr18   31904235   31904451  Syn-T1_MACS_peak_120646   53.28      +
# ...      ...        ...        ...                      ...     ...    ...
# 12571  chr18   30288750   30288819  Syn-T1_MACS_peak_120468  230.02      +
# 12572  chr18   30330599   30330835  Syn-T1_MACS_peak_120472  103.61      +
# 12573  chr18   31635981   31636058  Syn-T1_MACS_peak_120601   71.21      +
# 12575  chr18   32264623   32264665  Syn-T1_MACS_peak_120698   48.50      +
# 12577  chr18   35696977   35697123  Syn-T1_MACS_peak_121060   86.57      -
#
# ...

# %%
file_path = r''

d6syn_mrna_up = pd.read_excel(file_path,sheet_name=2,header=10)

d6syn_mrna_down = pd.read_excel(file_path,sheet_name=3,header=10)

d6syn_mrna_up
# Out:
#                  gene_id      logFC    logCPM             F    PValue  FDR  \
# 0     ENSMUSG00000029368  15.655267  7.701052  3.982036e+00  0.134780    1
# 1     ENSMUSG00000033831  12.988127  4.980475  3.535267e+00  0.150485    1
# 2     ENSMUSG00000025479  12.371293  4.422114  3.560470e+00  0.148583    1
# 3     ENSMUSG00000058207  12.307480  4.466723  3.958409e+00  0.133734    1
# 4     ENSMUSG00000056035  12.166927  4.137648  3.859573e+00  0.137104    1
# ...                  ...        ...       ...           ...       ...  ...
# 8769  ENSMUSG00000038366   0.000196  6.068821  2.632358e-06  0.998736    1
# 8770  ENSMUSG00000027776   0.000183 -1.819538  2.755449e-06  0.998710    1
# 8771  ENSMUSG00000001285   0.000075  3.750317  1.354769e-07  0.999713    1
# 8772  ENSMUSG00000035849   0.000049  5.461104  9.924165e-08  0.999755    1
# 8773  ENSMUSG00000032952   0.000003  3.805852  2.043069e-12  0.999999    1
#
# ...

# %%
d6syn_mrna_down
# Out:
#                  gene_id     logFC    logCPM             F    PValue  FDR  \
# 0     ENSMUSG00000020713 -6.628354  3.048687  2.840093e+01  0.000428    1
# 1     ENSMUSG00000021342 -6.404933  1.913135  2.255746e+01  0.000701    1
# 2     ENSMUSG00000067996 -6.176557 -1.231664  7.591080e+00  0.026805    1
# 3     ENSMUSG00000067679 -6.076225 -1.295864  7.390384e+00  0.028306    1
# 4     ENSMUSG00000095779 -5.958134 -1.231437  1.177908e+01  0.008300    1
# ...                  ...       ...       ...           ...       ...  ...
# 8679  ENSMUSG00000056851 -0.000201  7.352389  4.890591e-06  0.998277    1
# 8680  ENSMUSG00000001983 -0.000189  3.629577  5.417044e-07  0.999427    1
# 8681  ENSMUSG00000035478 -0.000092  4.365950  1.803082e-07  0.999669    1
# 8682  ENSMUSG00000002504 -0.000091  3.557105  7.019369e-08  0.999794    1
# 8683  ENSMUSG00000029536 -0.000028  4.329093  4.641392e-09  0.999947    1
#
#      regulation  702Training.Input  722Training.Input  817Training.Input  ...  \
# ...

# %%
d1d20mrna = r''

d1mrna_up = pd.read_excel(d1d20mrna,sheet_name=0,header=10)

d1mrna_down = pd.read_excel(d1d20mrna,sheet_name=1,header=10)

d20mrna_up = pd.read_excel(d1d20mrna,sheet_name=2,header=10)

d20mrna_down = pd.read_excel(d1d20mrna,sheet_name=3,header=10)

d1mrna_up
# Out:
#                  gene_id         logFC     logCPM    PValue  FDR regulation  \
# 0     ENSMUSG00000030559  3.170021e+00  -0.094280  0.189143    1         up
# 1     ENSMUSG00000041534  3.163290e+00   0.228471  0.275707    1         up
# 2     ENSMUSG00000006585  2.807448e+00  -0.658608  0.225856    1         up
# 3     ENSMUSG00000089756  2.734020e+00   1.042427  0.363618    1         up
# 4     ENSMUSG00000057137  2.661471e+00   1.077364  0.363807    1         up
# ...                  ...           ...        ...       ...  ...        ...
# 8440  ENSMUSG00000030465  1.313108e-04  10.075169  0.999993    1         up
# 8441  ENSMUSG00000033902  1.252766e-04   6.014911  1.000000    1         up
# 8442  ENSMUSG00000030521  1.137259e-04   3.790602  1.000000    1         up
# 8443  ENSMUSG00000032373  8.613403e-07   7.046941  1.000000    1         up
# 8444  ENSMUSG00000071645  8.501549e-07   3.705558  1.000000    1         up
#
# ...

# %%
d20mrna_down
# Out:
#                  gene_id     logFC    logCPM    PValue  FDR regulation  \
# 0     ENSMUSG00000045868 -4.502728  1.751518  0.144921    1       down
# 1     ENSMUSG00000093996 -3.349412 -0.645929  0.189143    1       down
# 2     ENSMUSG00000096856 -3.277239  0.194697  0.246766    1       down
# 3     ENSMUSG00000025722 -3.197073 -0.600396  0.205506    1       down
# 4     ENSMUSG00000079677 -2.726294 -0.657151  0.252005    1       down
# ...                  ...       ...       ...       ...  ...        ...
# 8201  ENSMUSG00000026577 -0.000277  4.464790  1.000000    1       down
# 8202  ENSMUSG00000021198 -0.000125  7.702636  1.000000    1       down
# 8203  ENSMUSG00000034647 -0.000073  7.966609  1.000000    1       down
# 8204  ENSMUSG00000004929 -0.000058  4.247900  1.000000    1       down
# 8205  ENSMUSG00000058558 -0.000030  7.488387  1.000000    1       down
#
#       Syn-T20  Syn-C20  Syn-T20.1  Syn-C20.1 gene_name    gene_biotype  \
# ...

# %%
d1_mrna = pd.concat([d1mrna_up,d1mrna_down],axis=0)

d20_mrna = pd.concat([d20mrna_up,d20mrna_down],axis=0)

d6_mrna = pd.concat([d6syn_mrna_up,d6syn_mrna_down],axis=0)

d1_mrna
# Out:
#                  gene_id     logFC    logCPM    PValue  FDR regulation  \
# 0     ENSMUSG00000030559  3.170021 -0.094280  0.189143    1         up
# 1     ENSMUSG00000041534  3.163290  0.228471  0.275707    1         up
# 2     ENSMUSG00000006585  2.807448 -0.658608  0.225856    1         up
# 3     ENSMUSG00000089756  2.734020  1.042427  0.363618    1         up
# 4     ENSMUSG00000057137  2.661471  1.077364  0.363807    1         up
# ...                  ...       ...       ...       ...  ...        ...
# 8170  ENSMUSG00000032477 -0.000415  2.083155  1.000000    1       down
# 8171  ENSMUSG00000002957 -0.000391  7.896058  1.000000    1       down
# 8172  ENSMUSG00000071655 -0.000240  5.269748  1.000000    1       down
# 8173  ENSMUSG00000004902 -0.000182  5.875903  1.000000    1       down
# 8174  ENSMUSG00000046032 -0.000137  5.074112  1.000000    1       down
#
#       Syn-T1  Syn-C1  Syn-T1.1  Syn-C1.1 gene_name    gene_biotype    GeneID  \
# ...

# %%
d6_mrna
# Out:
#                  gene_id      logFC    logCPM             F    PValue  FDR  \
# 0     ENSMUSG00000029368  15.655267  7.701052  3.982036e+00  0.134780    1
# 1     ENSMUSG00000033831  12.988127  4.980475  3.535267e+00  0.150485    1
# 2     ENSMUSG00000025479  12.371293  4.422114  3.560470e+00  0.148583    1
# 3     ENSMUSG00000058207  12.307480  4.466723  3.958409e+00  0.133734    1
# 4     ENSMUSG00000056035  12.166927  4.137648  3.859573e+00  0.137104    1
# ...                  ...        ...       ...           ...       ...  ...
# 8679  ENSMUSG00000056851  -0.000201  7.352389  4.890591e-06  0.998277    1
# 8680  ENSMUSG00000001983  -0.000189  3.629577  5.417044e-07  0.999427    1
# 8681  ENSMUSG00000035478  -0.000092  4.365950  1.803082e-07  0.999669    1
# 8682  ENSMUSG00000002504  -0.000091  3.557105  7.019369e-08  0.999794    1
# 8683  ENSMUSG00000029536  -0.000028  4.329093  4.641392e-09  0.999947    1
#
# ...

# %%
d20_mrna
# Out:
#                  gene_id     logFC    logCPM    PValue  FDR regulation  \
# 0     ENSMUSG00000028298  5.069170  1.447424  0.099905    1         up
# 1     ENSMUSG00000021342  4.173989  5.315848  0.196248    1         up
# 2     ENSMUSG00000020713  3.483195  7.356918  0.270358    1         up
# 3     ENSMUSG00000027120  3.126580 -0.953709  0.205506    1         up
# 4     ENSMUSG00000054667  2.701218  0.282777  0.348377    1         up
# ...                  ...       ...       ...       ...  ...        ...
# 8201  ENSMUSG00000026577 -0.000277  4.464790  1.000000    1       down
# 8202  ENSMUSG00000021198 -0.000125  7.702636  1.000000    1       down
# 8203  ENSMUSG00000034647 -0.000073  7.966609  1.000000    1       down
# 8204  ENSMUSG00000004929 -0.000058  4.247900  1.000000    1       down
# 8205  ENSMUSG00000058558 -0.000030  7.488387  1.000000    1       down
#
#       Syn-T20  Syn-C20  Syn-T20.1  Syn-C20.1 gene_name    gene_biotype  \
# ...

# %%
d6_up_isinse_isinmrna = d6_up_isinse[d6_up_isinse['GeneName'].isin(d6_mrna['gene_name'])]

d6_down_isinse_isinmrna = d6_down_isinse[d6_down_isinse['GeneName'].isin(d6_mrna['gene_name'])]

d6_up_isinse_isinmrna
# Out:
#        chrom       start         end                       PeakID    score  \
# 0      chr12  36023904.0  36024072.0  Learned-syn_MACS_peak_16231   520.51
# 1      chr12  38827777.0  38827907.0  Learned-syn_MACS_peak_16312  1009.12
# 3      chr12  49384294.0  49385641.0  Learned-syn_MACS_peak_16490  3100.00
# 4      chr12  51691421.0  51691914.0  Learned-syn_MACS_peak_16530  2263.87
# 5      chr12  52886713.0  52887591.0  Learned-syn_MACS_peak_16578  1731.59
# ...      ...         ...         ...                          ...      ...
# 18719  chr12  33147801.0  33147915.0  Learned-syn_MACS_peak_16159   499.13
# 18720  chr12  33148432.0  33148477.0  Learned-syn_MACS_peak_16160   499.13
# 18721  chr12  33371989.0  33372235.0  Learned-syn_MACS_peak_16183  2971.91
# 18722  chr12  35103120.0  35103140.0  Learned-syn_MACS_peak_16222    80.66
# 18723  chr12  35145499.0  35145718.0  Learned-syn_MACS_peak_16226  3100.00
#
# ...

# %%
d6_down_isinse_isinmrna
# Out:
#        chrom     start       end                        PeakID    score  \
# 0      chr12  38831080  38831269   Learned-syn_MACS_peak_16313   967.99
# 2      chr12  44290642  44290660   Learned-syn_MACS_peak_16408   357.26
# 3      chr12  51647993  51648135   Learned-syn_MACS_peak_16526   427.10
# 4      chr12  51829202  51829305   Learned-syn_MACS_peak_16545   143.17
# 8      chr12  55820661  55820792   Learned-syn_MACS_peak_16695  1512.54
# ...      ...       ...       ...                           ...      ...
# 19446   chr4  58437098  58437634  Control-syn1_MACS_peak_48026   100.17
# 19447   chr4  58487141  58487224  Control-syn1_MACS_peak_48027   465.16
# 19448   chr4  58504621  58504858  Control-syn1_MACS_peak_48028   786.05
# 19449   chr4  58553133  58553291  Control-syn1_MACS_peak_48029   453.16
# 19463   chr4  62204532  62204650  Control-syn1_MACS_peak_48084   187.74
#
#       strand  log2FoldChange Regulation  Learned-syn  Control-syn1  ...  \
# ...

# %%
d1_up_isinse_isinmrna = d1_up_isinse[d1_up_isinse['GeneName'].isin(d1_mrna['gene_name'])]

d1_down_isinse_isinmrna = d1_down_isinse[d1_down_isinse['GeneName'].isin(d1_mrna['gene_name'])]

d1_up_isinse_isinmrna
# Out:
#        chrom      start        end                   PeakID   score strand  \
# 2       chr4  140702146  140702435  Syn-T1_MACS_peak_183771  299.00      +
# 5      chr17   74338986   74339445  Syn-T1_MACS_peak_115699  197.66      +
# 7      chr18   30277050   30277115  Syn-T1_MACS_peak_120465  230.02      +
# 8      chr18   31904235   31904451  Syn-T1_MACS_peak_120646   53.28      +
# 9      chr18   36768086   36768203  Syn-T1_MACS_peak_121240  110.65      -
# ...      ...        ...        ...                      ...     ...    ...
# 12571  chr18   30288750   30288819  Syn-T1_MACS_peak_120468  230.02      +
# 12572  chr18   30330599   30330835  Syn-T1_MACS_peak_120472  103.61      +
# 12573  chr18   31635981   31636058  Syn-T1_MACS_peak_120601   71.21      +
# 12575  chr18   32264623   32264665  Syn-T1_MACS_peak_120698   48.50      +
# 12577  chr18   35696977   35697123  Syn-T1_MACS_peak_121060   86.57      -
#
# ...

# %%
d1_down_isinse_isinmrna
# Out:
#        chrom      start        end                   PeakID   score strand  \
# 1      chr18   79109187   79109391  Syn-T1_MACS_peak_125860   52.40      -
# 2      chr19    6363918    6364118  Syn-T1_MACS_peak_127476   82.32      +
# 3       chr4  118385013  118385307  Syn-T1_MACS_peak_180393   88.47      -
# 5       chr4  123917432  123917702  Syn-T1_MACS_peak_181238   70.49      +
# 6       chr4  124861632  124861887  Syn-T1_MACS_peak_181374  139.78      -
# ...      ...        ...        ...                      ...     ...    ...
# 15459   chr2   93811901   93811986  Syn-C1_MACS_peak_127252  355.09      -
# 15460   chr2  103467076  103467128  Syn-C1_MACS_peak_127996   43.07      -
# 15461   chr2  103484972  103485160  Syn-C1_MACS_peak_128001   44.85      -
# 15465   chr2  114121204  114121314  Syn-C1_MACS_peak_128900  114.86      -
# 15466   chr2  117300442  117300574  Syn-C1_MACS_peak_129115   84.13      -
#
# ...

# %%
d20_up_isinse_isinmrna = d20_up_isinse[d20_up_isinse['GeneName'].isin(d20_mrna['gene_name'])]

d20_down_isinse_isinmrna = d20_down_isinse[d20_down_isinse['GeneName'].isin(d20_mrna['gene_name'])]

d20_up_isinse_isinmrna
# Out:
#        chrom     start       end                   PeakID   score strand  \
# 2      chr15  98125025  98125090  Syn-T20_MACS_peak_86564  184.42      +
# 4      chr16   5073321   5073468  Syn-T20_MACS_peak_87708  147.68      +
# 5      chr16  20715908  20716509  Syn-T20_MACS_peak_89915  328.57      -
# 6      chr16  22500223  22500401  Syn-T20_MACS_peak_90134  273.35      -
# 8      chr16  91011092  91011308  Syn-T20_MACS_peak_96314   76.83      -
# ...      ...       ...       ...                      ...     ...    ...
# 15241  chr17  25243214  25243486  Syn-T20_MACS_peak_99906   81.16      -
# 15247  chr15  72685282  72685373  Syn-T20_MACS_peak_83151   40.78      -
# 15248  chr15  72903556  72903681  Syn-T20_MACS_peak_83185   41.64      -
# 15249  chr15  73295352  73295375  Syn-T20_MACS_peak_83255   68.22      -
# 15254  chr15  76331230  76331266  Syn-T20_MACS_peak_83632  113.54      +
#
#        log2FoldChange Regulation  Syn-T20  Syn-C20  ... GeneName    GeneID  \
# ...

# %%
d20_down_isinse_isinmrna
# Out:
#        chrom     start       end                   PeakID   score strand  \
# 0      chr15  77777767  77777928  Syn-T20_MACS_peak_83902   79.63      -
# 1      chr15  77779989  77780059  Syn-T20_MACS_peak_83904  204.81      -
# 3      chr15  81388329  81388400  Syn-T20_MACS_peak_84528   83.57      -
# 4      chr15  83388514  83388670  Syn-T20_MACS_peak_84862   50.76      -
# 5      chr15  83610153  83610351  Syn-T20_MACS_peak_84889  102.85      -
# ...      ...       ...       ...                      ...     ...    ...
# 17004  chr12  73941960  73942314  Syn-C20_MACS_peak_39124   54.03      +
# 17005  chr12  74238180  74238370  Syn-C20_MACS_peak_39171   64.70      +
# 17009  chr12  78845225  78845304  Syn-C20_MACS_peak_39526  105.64      -
# 17010  chr12  81026807  81027035  Syn-C20_MACS_peak_39742  203.83      +
# 17011  chr12  81496126  81496347  Syn-C20_MACS_peak_39802  323.94      -
#
#        log2FoldChange Regulation  Syn-T20  Syn-C20  ... GeneName    GeneID  \
# ...

# %%
d1_up_isinse_isinmrna_cds = d1_up_isinse_isinmrna[(d1_up_isinse_isinmrna['catalog'] != '5UTR') & (d1_up_isinse_isinmrna['catalog'] != '3UTR')]

d1_down_isinse_isinmrna_cds = d1_down_isinse_isinmrna[(d1_down_isinse_isinmrna['catalog'] != '5UTR') & (d1_down_isinse_isinmrna['catalog'] != '3UTR')]

d6_up_isinse_isinmrna_cds = d6_up_isinse_isinmrna[(d6_up_isinse_isinmrna['catalog'] != '5UTR') & (d6_up_isinse_isinmrna['catalog'] != '3UTR')]

d6_down_isinse_isinmrna_cds = d6_down_isinse_isinmrna[(d6_down_isinse_isinmrna['catalog'] != '5UTR') & (d6_down_isinse_isinmrna['catalog'] != '3UTR')]

d20_up_isinse_isinmrna_cds = d20_up_isinse_isinmrna[(d20_up_isinse_isinmrna['catalog'] != '5UTR') & (d20_up_isinse_isinmrna['catalog'] != '3UTR')]

d20_down_isinse_isinmrna_cds = d20_down_isinse_isinmrna[(d20_down_isinse_isinmrna['catalog'] != '5UTR') & (d20_down_isinse_isinmrna['catalog'] != '3UTR')]

d20_down_isinse_isinmrna_cds
# Out:
#        chrom     start       end                   PeakID   score strand  \
# 0      chr15  77777767  77777928  Syn-T20_MACS_peak_83902   79.63      -
# 1      chr15  77779989  77780059  Syn-T20_MACS_peak_83904  204.81      -
# 3      chr15  81388329  81388400  Syn-T20_MACS_peak_84528   83.57      -
# 4      chr15  83388514  83388670  Syn-T20_MACS_peak_84862   50.76      -
# 5      chr15  83610153  83610351  Syn-T20_MACS_peak_84889  102.85      -
# ...      ...       ...       ...                      ...     ...    ...
# 16999  chr12  66513181  66513231  Syn-C20_MACS_peak_38482  152.54      -
# 17004  chr12  73941960  73942314  Syn-C20_MACS_peak_39124   54.03      +
# 17005  chr12  74238180  74238370  Syn-C20_MACS_peak_39171   64.70      +
# 17009  chr12  78845225  78845304  Syn-C20_MACS_peak_39526  105.64      -
# 17010  chr12  81026807  81027035  Syn-C20_MACS_peak_39742  203.83      +
#
#        log2FoldChange Regulation  Syn-T20  Syn-C20  ... GeneName    GeneID  \
# ...

# %%
d1_isinse_isinmrna_cds = pd.concat([d1_up_isinse_isinmrna_cds,d1_down_isinse_isinmrna_cds],axis=0)

d1_isinse_isinmrna_cds_group = d1_isinse_isinmrna_cds.groupby('GeneName').sum()

# d1_isinse_isinmrna_cds_group新增一列'L-C'
d1_isinse_isinmrna_cds_group['L-C'] = d1_isinse_isinmrna_cds_group['Syn-T1'] - d1_isinse_isinmrna_cds_group['Syn-C1']

d1_isinse_isinmrna_cds_group
# Out:
#                                                            chrom       start  \
# GeneName
# 1500011B03Rik                                               chr5   114813779
# 1700003E16Rik                                           chr6chr6   166317314
# 1700025G04Rik                                           chr1chr1   303986990
# 1700066M21Rik                                               chr1    57382842
# 2210016L21Rik                                           chr5chr5   229889921
# ...                                                          ...         ...
# Zyg11b                                                  chr4chr4   216525766
# Zyx                                                     chr6chr6    84700083
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11c...  1020328104
# Zzz3                                                    chr3chr3   304874074
# l7Rn6                                                       chr7    89920108
#
# ...

# %%
d1_isinse_isinmrna_cds_group_sumup = d1_isinse_isinmrna_cds_group[d1_isinse_isinmrna_cds_group['L-C'] > 0]

d1_isinse_isinmrna_cds_group_sumdown = d1_isinse_isinmrna_cds_group[d1_isinse_isinmrna_cds_group['L-C'] < 0]

d1_isinse_isinmrna_cds_group_sumup
# Out:
#                           chrom      start        end  \
# GeneName
# 1500011B03Rik              chr5  114813779  114813848
# 2510009E07Rik             chr16   21694215   21694609
# 9930021J03Rik             chr19   29805281   29806009
# Abat            chr16chr16chr16   25772846   25773179
# Abcb7                      chrX  104301793  104301805
# ...                         ...        ...        ...
# Zmpste24               chr4chr4  242156059  242156209
# Zmynd11              chr13chr13   19419399   19419637
# Zmynd8         chr2chr2chr2chr2  663257096  663259266
# Znhit1                     chr5  136984878  136985049
# l7Rn6                      chr7   89920108   89920191
#
#                                                           PeakID   score  \
# GeneName
# 1500011B03Rik                            Syn-T1_MACS_peak_198872  228.67
# 2510009E07Rik                             Syn-T1_MACS_peak_98955   64.87
# ...

# %%
d1_isinse_isinmrna_cds_group_sumdown
# Out:
#                                                            chrom       start  \
# GeneName
# 1700003E16Rik                                           chr6chr6   166317314
# 1700025G04Rik                                           chr1chr1   303986990
# 1700066M21Rik                                               chr1    57382842
# 2210016L21Rik                                           chr5chr5   229889921
# 2310022B05Rik                                           chr8chr8   249301937
# ...                                                          ...         ...
# Zwint                                                      chr10    72654844
# Zyg11b                                                  chr4chr4   216525766
# Zyx                                                     chr6chr6    84700083
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11c...  1020328104
# Zzz3                                                    chr3chr3   304874074
#
# ...

# %%
d6_isinse_isinmrna_cds = pd.concat([d6_up_isinse_isinmrna_cds,d6_down_isinse_isinmrna_cds],axis=0)

d6_isinse_isinmrna_cds_group = d6_isinse_isinmrna_cds.groupby('GeneName').sum()

d6_isinse_isinmrna_cds_group
# Out:
#                                                            chrom        start  \
# GeneName
# 1110004F10Rik                                           chr7chr7  232205224.0
# 1500009C09Rik                                              chr15   82259564.0
# 1500011B03Rik                                               chr5  114813779.0
# 1700003E16Rik                                               chr6   83161845.0
# 1700025G04Rik                                   chr1chr1chr1chr1  607710378.0
# ...                                                          ...          ...
# Zswim6                                                     chr13  107889636.0
# Zwint                                                      chr10   72654900.0
# Zyg11b                                                  chr4chr4  216495369.0
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11c...  728551897.0
# Zzz3                                            chr3chr3chr3chr3  609787768.0
#
# ...

# %%
d6_isinse_isinmrna_cds_group['L-C'] = d6_isinse_isinmrna_cds_group['Learned-syn'] - d6_isinse_isinmrna_cds_group['Control-syn1']

d6_isinse_isinmrna_cds_group
# Out:
#                                                            chrom        start  \
# GeneName
# 1110004F10Rik                                           chr7chr7  232205224.0
# 1500009C09Rik                                              chr15   82259564.0
# 1500011B03Rik                                               chr5  114813779.0
# 1700003E16Rik                                               chr6   83161845.0
# 1700025G04Rik                                   chr1chr1chr1chr1  607710378.0
# ...                                                          ...          ...
# Zswim6                                                     chr13  107889636.0
# Zwint                                                      chr10   72654900.0
# Zyg11b                                                  chr4chr4  216495369.0
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11c...  728551897.0
# Zzz3                                            chr3chr3chr3chr3  609787768.0
#
# ...

# %%
d6_isinse_isinmrna_cds_group_sumup = d6_isinse_isinmrna_cds_group[d6_isinse_isinmrna_cds_group['L-C'] > 0]

d6_isinse_isinmrna_cds_group_sumdown = d6_isinse_isinmrna_cds_group[d6_isinse_isinmrna_cds_group['L-C'] < 0]

d6_isinse_isinmrna_cds_group_sumup
# Out:
#                                                            chrom        start  \
# GeneName
# 1110004F10Rik                                           chr7chr7  232205224.0
# 1500009C09Rik                                              chr15   82259564.0
# 2310022B05Rik                                   chr8chr8chr8chr8  498590976.0
# 2610507B11Rik                               chr11chr11chr11chr11  313087929.0
# 4833439L19Rik                                    chr13chr13chr13  163664589.0
# ...                                                          ...          ...
# Zrsr2                                               chrXchrXchrX  491864269.0
# Zswim6                                                     chr13  107889636.0
# Zyg11b                                                  chr4chr4  216495369.0
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11c...  728551897.0
# Zzz3                                            chr3chr3chr3chr3  609787768.0
#
# ...

# %%
d6_isinse_isinmrna_cds_group_sumdown
# Out:
#                           chrom        start          end  \
# GeneName
# 1500011B03Rik              chr5  114813779.0  114813916.0
# 1700003E16Rik              chr6   83161845.0   83162518.0
# 1700025G04Rik  chr1chr1chr1chr1  607710378.0  607710585.0
# 1700066M21Rik      chr1chr1chr1  172143660.0  172144164.0
# 1810037I17Rik              chr3  122924361.0  122924656.0
# ...                         ...          ...          ...
# Zmynd11         chr13chr13chr13   29123888.0   29124196.0
# Znhit1             chr5chr5chr5  410954753.0  410955642.0
# Zranb2                 chr3chr3  315074033.0  315074246.0
# Zrsr1                chr11chr11   45947335.0   45948791.0
# Zwint                     chr10   72654900.0   72654977.0
#
#                                                           PeakID    score  \
# GeneName
# 1500011B03Rik                       Control-syn1_MACS_peak_55002   679.16
# 1700003E16Rik                       Control-syn1_MACS_peak_59008   795.06
# ...

# %%
d20_isinse_isinmrna_cds = pd.concat([d20_up_isinse_isinmrna_cds,d20_down_isinse_isinmrna_cds],axis=0)

d20_isinse_isinmrna_cds_group = d20_isinse_isinmrna_cds.groupby('GeneName').sum()

d20_isinse_isinmrna_cds_group
# Out:
#                                                        chrom      start  \
# GeneName
# 1110004F10Rik                                           chr7  116099455
# 1500011B03Rik                                           chr5  114813779
# 1700025G04Rik                                           chr1  152006544
# 2510009E07Rik                                          chr16   21694215
# 2610301B20Rik                                           chr4   10898105
# ...                                                      ...        ...
# Zyg11b                                                  chr4  108300890
# Zyx                                                     chr6   42350256
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11  655670760
# Zzz3                                                    chr3  152458253
# l7Rn6                                               chr7chr7  179843690
#
#                      end                                             PeakID  \
# GeneName
# ...

# %%
d20_isinse_isinmrna_cds_group['L-C'] = d20_isinse_isinmrna_cds_group['Syn-T20'] - d20_isinse_isinmrna_cds_group['Syn-C20']

d20_isinse_isinmrna_cds_group
# Out:
#                                                        chrom      start  \
# GeneName
# 1110004F10Rik                                           chr7  116099455
# 1500011B03Rik                                           chr5  114813779
# 1700025G04Rik                                           chr1  152006544
# 2510009E07Rik                                          chr16   21694215
# 2610301B20Rik                                           chr4   10898105
# ...                                                      ...        ...
# Zyg11b                                                  chr4  108300890
# Zyx                                                     chr6   42350256
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11  655670760
# Zzz3                                                    chr3  152458253
# l7Rn6                                               chr7chr7  179843690
#
#                      end                                             PeakID  \
# GeneName
# ...

# %%
d20_isinse_isinmrna_cds_group_sumup = d20_isinse_isinmrna_cds_group[d20_isinse_isinmrna_cds_group['L-C'] > 0]

d20_isinse_isinmrna_cds_group_sumdown = d20_isinse_isinmrna_cds_group[d20_isinse_isinmrna_cds_group['L-C'] < 0]

d20_isinse_isinmrna_cds_group_sumup
# Out:
#                                       chrom      start        end  \
# GeneName
# 1700025G04Rik                          chr1  152006544  152006767
# 2610301B20Rik                          chr4   10898105   10898362
# 2610507B11Rik                    chr11chr11  156540777  156541986
# 2900026A02Rik                      chr5chr5  226195423  226195570
# 9530068E07Rik                         chr11   52396427   52396603
# ...                                     ...        ...        ...
# Zmym3          chrXchrXchrXchrXchrXchrXchrX  709884423  709885848
# Zmym6                  chr4chr4chr4chr4chr4  635554068  635555082
# Zswim5                 chr4chr4chr4chr4chr4  584780350  584781368
# Zyg11b                                 chr4  108300890  108301096
# Zyx                                    chr6   42350256   42350476
#
#                                                           PeakID    score  \
# GeneName
# 1700025G04Rik                            Syn-T20_MACS_peak_12840   245.55
# ...

# %%
d20_isinse_isinmrna_cds_group_sumdown
# Out:
#                                                        chrom      start  \
# GeneName
# 1110004F10Rik                                           chr7  116099455
# 1500011B03Rik                                           chr5  114813779
# 2510009E07Rik                                          chr16   21694215
# 5730455P16Rik                                     chr11chr11  160752308
# 9930021J03Rik                                     chr19chr19   59591529
# ...                                                      ...        ...
# Zrsr2                                                   chrX  163956471
# Zswim6                                            chr13chr13  215465037
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11  655670760
# Zzz3                                                    chr3  152458253
# l7Rn6                                               chr7chr7  179843690
#
#                      end                                             PeakID  \
# GeneName
# ...

# %% [markdown]
# ### 计算figs3f

# %%
d6_isinse_isinmrna_cds_group_reindex = d6_isinse_isinmrna_cds_group.reset_index()

d6_isinse_isinmrna_cds_group_reindex
# Out:
#            GeneName                                              chrom  \
# 0     1110004F10Rik                                           chr7chr7
# 1     1500009C09Rik                                              chr15
# 2     1500011B03Rik                                               chr5
# 3     1700003E16Rik                                               chr6
# 4     1700025G04Rik                                   chr1chr1chr1chr1
# ...             ...                                                ...
# 5143         Zswim6                                              chr13
# 5144          Zwint                                              chr10
# 5145         Zyg11b                                           chr4chr4
# 5146          Zzef1  chr11chr11chr11chr11chr11chr11chr11chr11chr11c...
# 5147           Zzz3                                   chr3chr3chr3chr3
#
#             start          end  \
# 0     232205224.0  232205324.0
# 1      82259564.0   82260624.0
# ...

# %%
d1_isinse_isinmrna_cds_group
# Out:
#                                                            chrom       start  \
# GeneName
# 1500011B03Rik                                               chr5   114813779
# 1700003E16Rik                                           chr6chr6   166317314
# 1700025G04Rik                                           chr1chr1   303986990
# 1700066M21Rik                                               chr1    57382842
# 2210016L21Rik                                           chr5chr5   229889921
# ...                                                          ...         ...
# Zyg11b                                                  chr4chr4   216525766
# Zyx                                                     chr6chr6    84700083
# Zzef1          chr11chr11chr11chr11chr11chr11chr11chr11chr11c...  1020328104
# Zzz3                                                    chr3chr3   304874074
# l7Rn6                                                       chr7    89920108
#
# ...

# %%
d6_isinse_isinmrna_cds_group_reindex ['fc'] =  d6_isinse_isinmrna_cds_group_reindex ['Learned-syn']/d6_isinse_isinmrna_cds_group_reindex ['Control-syn1']

d6_isinse_isinmrna_cds_group_reindex
# Out:
#            GeneName                                              chrom  \
# 0     1110004F10Rik                                           chr7chr7
# 1     1500009C09Rik                                              chr15
# 2     1500011B03Rik                                               chr5
# 3     1700003E16Rik                                               chr6
# 4     1700025G04Rik                                   chr1chr1chr1chr1
# ...             ...                                                ...
# 5143         Zswim6                                              chr13
# 5144          Zwint                                              chr10
# 5145         Zyg11b                                           chr4chr4
# 5146          Zzef1  chr11chr11chr11chr11chr11chr11chr11chr11chr11c...
# 5147           Zzz3                                   chr3chr3chr3chr3
#
#             start          end  \
# 0     232205224.0  232205324.0
# 1      82259564.0   82260624.0
# ...

# %%
import numpy as np
#计算log2fc
d6_isinse_isinmrna_cds_group_reindex ['sitelog2fc'] = np.log2(d6_isinse_isinmrna_cds_group_reindex ['fc'])

d6_isinse_isinmrna_cds_group_reindex
# Out:
#            GeneName                                              chrom  \
# 0     1110004F10Rik                                           chr7chr7
# 1     1500009C09Rik                                              chr15
# 2     1500011B03Rik                                               chr5
# 3     1700003E16Rik                                               chr6
# 4     1700025G04Rik                                   chr1chr1chr1chr1
# ...             ...                                                ...
# 5143         Zswim6                                              chr13
# 5144          Zwint                                              chr10
# 5145         Zyg11b                                           chr4chr4
# 5146          Zzef1  chr11chr11chr11chr11chr11chr11chr11chr11chr11c...
# 5147           Zzz3                                   chr3chr3chr3chr3
#
#             start          end  \
# 0     232205224.0  232205324.0
# 1      82259564.0   82260624.0
# ...

# %%
d6_mrna
# Out:
#                  gene_id      logFC    logCPM             F    PValue  FDR  \
# 0     ENSMUSG00000029368  15.655267  7.701052  3.982036e+00  0.134780    1
# 1     ENSMUSG00000033831  12.988127  4.980475  3.535267e+00  0.150485    1
# 2     ENSMUSG00000025479  12.371293  4.422114  3.560470e+00  0.148583    1
# 3     ENSMUSG00000058207  12.307480  4.466723  3.958409e+00  0.133734    1
# 4     ENSMUSG00000056035  12.166927  4.137648  3.859573e+00  0.137104    1
# ...                  ...        ...       ...           ...       ...  ...
# 8679  ENSMUSG00000056851  -0.000201  7.352389  4.890591e-06  0.998277    1
# 8680  ENSMUSG00000001983  -0.000189  3.629577  5.417044e-07  0.999427    1
# 8681  ENSMUSG00000035478  -0.000092  4.365950  1.803082e-07  0.999669    1
# 8682  ENSMUSG00000002504  -0.000091  3.557105  7.019369e-08  0.999794    1
# 8683  ENSMUSG00000029536  -0.000028  4.329093  4.641392e-09  0.999947    1
#
# ...

# %%
d6_mrna_dd = d6_mrna.drop_duplicates(subset='gene_name')

d6_mrna_dd
# Out:
#                  gene_id      logFC    logCPM             F    PValue  FDR  \
# 0     ENSMUSG00000029368  15.655267  7.701052  3.982036e+00  0.134780    1
# 1     ENSMUSG00000033831  12.988127  4.980475  3.535267e+00  0.150485    1
# 2     ENSMUSG00000025479  12.371293  4.422114  3.560470e+00  0.148583    1
# 3     ENSMUSG00000058207  12.307480  4.466723  3.958409e+00  0.133734    1
# 4     ENSMUSG00000056035  12.166927  4.137648  3.859573e+00  0.137104    1
# ...                  ...        ...       ...           ...       ...  ...
# 8679  ENSMUSG00000056851  -0.000201  7.352389  4.890591e-06  0.998277    1
# 8680  ENSMUSG00000001983  -0.000189  3.629577  5.417044e-07  0.999427    1
# 8681  ENSMUSG00000035478  -0.000092  4.365950  1.803082e-07  0.999669    1
# 8682  ENSMUSG00000002504  -0.000091  3.557105  7.019369e-08  0.999794    1
# 8683  ENSMUSG00000029536  -0.000028  4.329093  4.641392e-09  0.999947    1
#
# ...

# %%
d6_mrna_dd_test = d6_mrna.drop_duplicates(subset='gene_name',keep='last')

d6_mrna_dd_test
# Out:
#                  gene_id      logFC    logCPM             F    PValue  FDR  \
# 0     ENSMUSG00000029368  15.655267  7.701052  3.982036e+00  0.134780    1
# 1     ENSMUSG00000033831  12.988127  4.980475  3.535267e+00  0.150485    1
# 2     ENSMUSG00000025479  12.371293  4.422114  3.560470e+00  0.148583    1
# 3     ENSMUSG00000058207  12.307480  4.466723  3.958409e+00  0.133734    1
# 4     ENSMUSG00000056035  12.166927  4.137648  3.859573e+00  0.137104    1
# ...                  ...        ...       ...           ...       ...  ...
# 8679  ENSMUSG00000056851  -0.000201  7.352389  4.890591e-06  0.998277    1
# 8680  ENSMUSG00000001983  -0.000189  3.629577  5.417044e-07  0.999427    1
# 8681  ENSMUSG00000035478  -0.000092  4.365950  1.803082e-07  0.999669    1
# 8682  ENSMUSG00000002504  -0.000091  3.557105  7.019369e-08  0.999794    1
# 8683  ENSMUSG00000029536  -0.000028  4.329093  4.641392e-09  0.999947    1
#
# ...

# %%
d6_isinse_isinmrna_cds_group_reindex_sumfcup = d6_isinse_isinmrna_cds_group_reindex[d6_isinse_isinmrna_cds_group_reindex[ 'fc'] > 1]

d6_isinse_isinmrna_cds_group_reindex_sumfcup
# Out:
#            GeneName                                              chrom  \
# 0     1110004F10Rik                                           chr7chr7
# 1     1500009C09Rik                                              chr15
# 8     2310022B05Rik                                   chr8chr8chr8chr8
# 9     2610507B11Rik                               chr11chr11chr11chr11
# 11    4833439L19Rik                                    chr13chr13chr13
# ...             ...                                                ...
# 5142          Zrsr2                                       chrXchrXchrX
# 5143         Zswim6                                              chr13
# 5145         Zyg11b                                           chr4chr4
# 5146          Zzef1  chr11chr11chr11chr11chr11chr11chr11chr11chr11c...
# 5147           Zzz3                                   chr3chr3chr3chr3
#
#             start          end  \
# 0     232205224.0  232205324.0
# 1      82259564.0   82260624.0
# ...

# %%
d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna = pd.merge(d6_isinse_isinmrna_cds_group_reindex_sumfcup,d6_mrna_dd,left_on='GeneName',right_on='gene_name',how='left')

d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna
# Out:
#            GeneName                                              chrom  \
# 0     1110004F10Rik                                           chr7chr7
# 1     1500009C09Rik                                              chr15
# 2     2310022B05Rik                                   chr8chr8chr8chr8
# 3     2610507B11Rik                               chr11chr11chr11chr11
# 4     4833439L19Rik                                    chr13chr13chr13
# ...             ...                                                ...
# 2755          Zrsr2                                       chrXchrXchrX
# 2756         Zswim6                                              chr13
# 2757         Zyg11b                                           chr4chr4
# 2758          Zzef1  chr11chr11chr11chr11chr11chr11chr11chr11chr11c...
# 2759           Zzz3                                   chr3chr3chr3chr3
#
#             start          end  \
# 0     232205224.0  232205324.0
# 1      82259564.0   82260624.0
# ...

# %%
d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnaup = d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna[d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna['logFC'] > 1]

d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnaup
# Out:
#       GeneName                                          chrom        start  \
# 905       Gga1                                chr15chr15chr15  236678932.0
# 1175     Kifc3                       chr8chr8chr8chr8chr8chr8  570633141.0
# 1422    Ncaph2                                          chr15   89364087.0
# 1855    Rab40c                                     chr17chr17   51768386.0
# 1859    Rabac1                                       chr7chr7   49941509.0
# 1873  Rap1gap2  chr11chr11chr11chr11chr11chr11chr11chr11chr11  669698173.0
# 1915     Reep6                                     chr10chr10  160669074.0
# 2127   Slc12a4                                       chr8chr8  211898157.0
# 2287    Stard3                                          chr11   98376751.0
#
#               end                                             PeakID    score  \
# 905   236679453.0  Learned-syn_MACS_peak_27918Learned-syn_MACS_pe...  2580.57
# ...

# %%
d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnadown = d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna[d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna['logFC'] < -1]

d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnadown
# Out:
#      GeneName                      chrom        start          end  \
# 640     Dhx15                   chr5chr5  104360199.0  104360614.0
# 654      Dlk1                 chr12chr12  218908946.0  218909267.0
# 742      Elp3            chr14chr14chr14  196642664.0  196642916.0
# 953      Gpd1  chr15chr15chr15chr15chr15  498598825.0  498599769.0
# 1487     Nme2                      chr11   93951963.0   93952012.0
# 1932   Rhbdl1                 chr17chr17   51672366.0   51672526.0
# 2168  Slc44a2                       chr9   21341938.0   21342023.0
# 2428  Tmem147               chr7chr7chr7   92185531.0   92186005.0
#
#                                                  PeakID    score strand  \
# 640   Learned-syn_MACS_peak_59658Learned-syn_MACS_pe...   724.49     --
# 654   Learned-syn_MACS_peak_18386Control-syn1_MACS_p...  3991.78     ++
# 742   Learned-syn_MACS_peak_24258Learned-syn_MACS_pe...  3156.60    ---
# 953   Learned-syn_MACS_peak_28973Learned-syn_MACS_pe...  4050.82  +++++
# ...

# %%
d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnans = d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna[(d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna['logFC'] >= -1) & (d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna['logFC'] <= 1)]

d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnans
# Out:
#            GeneName                                              chrom  \
# 0     1110004F10Rik                                           chr7chr7
# 1     1500009C09Rik                                              chr15
# 2     2310022B05Rik                                   chr8chr8chr8chr8
# 3     2610507B11Rik                               chr11chr11chr11chr11
# 4     4833439L19Rik                                    chr13chr13chr13
# ...             ...                                                ...
# 2755          Zrsr2                                       chrXchrXchrX
# 2756         Zswim6                                              chr13
# 2757         Zyg11b                                           chr4chr4
# 2758          Zzef1  chr11chr11chr11chr11chr11chr11chr11chr11chr11c...
# 2759           Zzz3                                   chr3chr3chr3chr3
#
#             start          end  \
# 0     232205224.0  232205324.0
# 1      82259564.0   82260624.0
# ...

# %%
d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnaup_redplot = d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnaup[['GeneName','sitelog2fc','logFC']]

d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnaup_redplot
# Out:
#       GeneName  sitelog2fc     logFC
# 905       Gga1    2.128351  1.954208
# 1175     Kifc3    0.721299  1.551493
# 1422    Ncaph2    2.384050  1.845401
# 1855    Rab40c    0.117912  1.790761
# 1859    Rabac1    2.545968  2.396091
# 1873  Rap1gap2    3.295068  2.236032
# 1915     Reep6    0.895112  1.199779
# 2127   Slc12a4    1.429155  1.514713
# 2287    Stard3    5.028127  1.366580

# %%
d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnadown_blueplot = d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnadown[['GeneName','sitelog2fc','logFC']]

d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnadown_blueplot
# Out:
#      GeneName  sitelog2fc     logFC
# 640     Dhx15    3.217231 -1.202097
# 654      Dlk1    1.378322 -2.850902
# 742      Elp3    1.037251 -3.690738
# 953      Gpd1    3.797636 -1.214568
# 1487     Nme2    4.416164 -1.159609
# 1932   Rhbdl1    3.998196 -1.649377
# 2168  Slc44a2    2.307429 -1.830779
# 2428  Tmem147    0.699427 -2.382474

# %%
d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnans_greyplot = d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnans[['GeneName','sitelog2fc','logFC']]

d6_isinse_isinmrna_cds_group_reindex_sumfcup_mergemrna_mrnans_greyplot
# Out:
#            GeneName  sitelog2fc     logFC
# 0     1110004F10Rik    0.212456 -0.119023
# 1     1500009C09Rik    2.608387  0.364419
# 2     2310022B05Rik    0.654756 -0.251848
# 3     2610507B11Rik    0.550093  0.015322
# 4     4833439L19Rik    2.835250  0.170294
# ...             ...         ...       ...
# 2755          Zrsr2    0.168467  0.142372
# 2756         Zswim6    5.356144  0.029869
# 2757         Zyg11b    3.746850 -0.044491
# 2758          Zzef1    1.652109 -0.011140
# 2759           Zzz3    0.700491 -0.012534
#
# [2743 rows x 3 columns]

# %%
# writer = pd.ExcelWriter(r'H:\d6周海倩+2022020702&2022091526+Supplementary+Analysis+b20231013\散点图\根据figs3b中的sumup基因以及其mrna的logfc绘制的figs3f散点图.xlsx')
# 
# d6_isinse_isinmrna_cds_group_sumup_mergemrna.to_excel(writer,sheet_name='d6_isinsemrna_cdssumup_mrna',index = False)
# 
# d6_isinse_isinmrna_cds_group_sumup_mergemrna_mrnaup.to_excel(writer,sheet_name='d6_isinsemrna_cdssumup_mrnaup',index = False)
# 
# d6_isinse_isinmrna_cds_group_sumup_mergemrna_mrnans.to_excel(writer,sheet_name='d6_isinsemrna_cdssumup_mrnans',index = False)
# 
# d6_isinse_isinmrna_cds_group_sumup_mergemrna_mrnadown.to_excel(writer,sheet_name='d6_isinsemrna_cdssumup_mrnadown',index = False)
# 
# d6_isinse_isinmrna_cds_group_sumup_mergemrna_mrnadown_blueplot.to_excel(writer,sheet_name='d6_semrna_cdssup_mrnadown_blue',index = False)
# 
# d6_isinse_isinmrna_cds_group_sumup_mergemrna_mrnaup_redplot.to_excel(writer,sheet_name='d6_semrna_cdssumup_mrnaup_red',index = False)
# 
# d6_isinse_isinmrna_cds_group_sumup_mergemrna_mrnans_greyplot.to_excel(writer,sheet_name='d6_semrna_cdssumup_mrnans_grey',index = False)
# 
# writer.close()

# %%
# writer = pd.ExcelWriter(r'H:\d1d20周海倩 2023111032 Mouse AcRIP-ac4C-mRNA Sequencing Report 20240106\周海倩 2023111032 Mouse AcRIP-ac4C-mRNA Sequencing Report 20240106\figs3b折线图\d1d6d20ac4cmrna的peak求和聚合后根据求和的fe计算L-C，而后根据L-C是否大于0分为sumup和sumdown.xlsx')
# 
# d1_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d1_insemrna_cds_group_sumup',index = True)
# 
# d1_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d1_insemrna_cds_group_sumdown',index = True)
# 
# d6_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d6_insemrna_cds_group_sumup',index = True)
# 
# d6_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d6_insemrna_cds_group_sumdown',index = True)
# 
# d20_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d20_insemrna_cds_group_sumup',index = True)
# 
# d20_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d20_insemrna_cds_group_sumdown',index = True)
# 
# writer.close()

# %%
# d1_up_isinse_isinmrna_cds_group = d1_up_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d1_down_isinse_isinmrna_cds_group = d1_down_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d6_up_isinse_isinmrna_cds_group = d6_up_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d6_down_isinse_isinmrna_cds_group = d6_down_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d20_up_isinse_isinmrna_cds_group = d20_up_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d20_down_isinse_isinmrna_cds_group = d20_down_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d20_down_isinse_isinmrna_cds_group

# %%
# #新增两列’upT1fe‘'upC1fe'，值为Syn-T1,Syn-C1的值
# d1_up_isinse_isinmrna_cds['adjT1fe'] = d1_up_isinse_isinmrna_cds['Syn-T1']
# d1_up_isinse_isinmrna_cds['adjC1fe'] = d1_up_isinse_isinmrna_cds['Syn-C1']
# 
# d6_up_isinse_isinmrna_cds['adjT6fe'] = d6_up_isinse_isinmrna_cds['Learned-syn']
# d6_up_isinse_isinmrna_cds['adjC6fe'] = d6_up_isinse_isinmrna_cds['Control-syn1']
# 
# d20_up_isinse_isinmrna_cds['adjT20fe'] = d20_up_isinse_isinmrna_cds['Syn-T20']
# d20_up_isinse_isinmrna_cds['adjC20fe'] = d20_up_isinse_isinmrna_cds['Syn-C20']
# 
# d1_up_isinse_isinmrna_cds

# %%
# #新增两列’downT1fe‘'downC1fe'，值为-Syn-T1,-Syn-C1的值
# d1_down_isinse_isinmrna_cds['adjT1fe'] = -d1_down_isinse_isinmrna_cds['Syn-T1']
# d1_down_isinse_isinmrna_cds['adjC1fe'] = -d1_down_isinse_isinmrna_cds['Syn-C1']
# 
# d6_down_isinse_isinmrna_cds['adjT6fe'] = -d6_down_isinse_isinmrna_cds['Learned-syn']
# d6_down_isinse_isinmrna_cds['adjC6fe'] = -d6_down_isinse_isinmrna_cds['Control-syn1']
# 
# d20_down_isinse_isinmrna_cds['adjT20fe'] = -d20_down_isinse_isinmrna_cds['Syn-T20']
# d20_down_isinse_isinmrna_cds['adjC20fe'] = -d20_down_isinse_isinmrna_cds['Syn-C20']
# 
# d1_down_isinse_isinmrna_cds

# %%
# d1_isinse_isinmrna_cds = pd.concat([d1_up_isinse_isinmrna_cds,d1_down_isinse_isinmrna_cds],axis=0)
# 
# d1_isinse_isinmrna_cds_group = d1_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d1_isinse_isinmrna_cds_group

# %%
# #新增一列'adjfc'，值为adjT1fe/adjC1fe
# d1_isinse_isinmrna_cds_group['adjfc'] = d1_isinse_isinmrna_cds_group['adjT1fe']/d1_isinse_isinmrna_cds_group['adjC1fe']
# 
# d1_isinse_isinmrna_cds_group

# %%
# d1_isinse_isinmrna_cds_group_sumup = d1_isinse_isinmrna_cds_group[d1_isinse_isinmrna_cds_group['adjfc'] > 0]
# 
# d1_isinse_isinmrna_cds_group_sumdown = d1_isinse_isinmrna_cds_group[d1_isinse_isinmrna_cds_group['adjfc'] < 0]
# 
# d1_isinse_isinmrna_cds_group_sumup

# %%
# d1_isinse_isinmrna_cds_group_sumdown

# %%
# d6_isinse_isinmrna_cds = pd.concat([d6_up_isinse_isinmrna_cds,d6_down_isinse_isinmrna_cds],axis=0)
# 
# d6_isinse_isinmrna_cds_group = d6_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d6_isinse_isinmrna_cds_group

# %%
# d6_isinse_isinmrna_cds_group['adjfc'] = d6_isinse_isinmrna_cds_group['adjT6fe']/d6_isinse_isinmrna_cds_group['adjC6fe']
# 
# d6_isinse_isinmrna_cds_group

# %%
# d6_isinse_isinmrna_cds_group_sumup = d6_isinse_isinmrna_cds_group[d6_isinse_isinmrna_cds_group['adjfc'] > 0]
# 
# d6_isinse_isinmrna_cds_group_sumdown = d6_isinse_isinmrna_cds_group[d6_isinse_isinmrna_cds_group['adjfc'] < 0]
# 
# d6_isinse_isinmrna_cds_group_sumup

# %%
# d6_isinse_isinmrna_cds_group_sumdown

# %%
# d20_isinse_isinmrna_cds = pd.concat([d20_up_isinse_isinmrna_cds,d20_down_isinse_isinmrna_cds],axis=0)
# 
# d20_isinse_isinmrna_cds_group = d20_isinse_isinmrna_cds.groupby('GeneName').sum()
# 
# d20_isinse_isinmrna_cds_group

# %%
# d20_isinse_isinmrna_cds_group['adjfc'] = d20_isinse_isinmrna_cds_group['adjT20fe']/d20_isinse_isinmrna_cds_group['adjC20fe']
# 
# d20_isinse_isinmrna_cds_group

# %%
# d20_isinse_isinmrna_cds_group_sumup = d20_isinse_isinmrna_cds_group[d20_isinse_isinmrna_cds_group['adjfc'] > 0]
# 
# d20_isinse_isinmrna_cds_group_sumdown = d20_isinse_isinmrna_cds_group[d20_isinse_isinmrna_cds_group['adjfc'] < 0]
# 
# d20_isinse_isinmrna_cds_group_sumup

# %%
# d20_isinse_isinmrna_cds_group_sumdown

# %%
# writer = pd.ExcelWriter(r'H:\d1d20周海倩 2023111032 Mouse AcRIP-ac4C-mRNA Sequencing Report 20240106\周海倩 2023111032 Mouse AcRIP-ac4C-mRNA Sequencing Report 20240106\figs3b折线图\d1d6d20ac4cmrna的peak中将down中t组和c组的fe设为负值，合并聚合后根据求和的fe计算fc，而后根据fc是否大于0分为sumup和sumdown.xlsx')
# 
# d1_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d1_insemrna_cds_group_sumup',index = True)
# 
# d1_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d1_insemrna_cds_group_sumdown',index = True)
# 
# d6_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d6_insemrna_cds_group_sumup',index = True)
# 
# d6_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d6_insemrna_cds_group_sumdown',index = True)
# 
# d20_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d20_insemrna_cds_group_sumup',index = True)
# 
# d20_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d20_insemrna_cds_group_sumdown',index = True)
# 
# writer.close()

# %%
# writer = pd.ExcelWriter(r'H:\d1d20周海倩 2023111032 Mouse AcRIP-ac4C-mRNA Sequencing Report 20240106\周海倩 2023111032 Mouse AcRIP-ac4C-mRNA Sequencing Report 20240106\figs3b折线图\d1d6d20ac4cmrna的peak中大cds组的求和，根据新fc是否大于1分为sumup和sumdown组.xlsx')
# 
# d1_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d1_insemrna_cds_group_sumup',index = True)
# 
# d1_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d1_insemrna_cds_group_sumdown',index = True)
# 
# d6_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d6_insemrna_cds_group_sumup',index = True)
# 
# d6_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d6_insemrna_cds_group_sumdown',index = True)
# 
# d20_isinse_isinmrna_cds_group_sumup.to_excel(writer,sheet_name='d20_insemrna_cds_group_sumup',index = True)
# 
# d20_isinse_isinmrna_cds_group_sumdown.to_excel(writer,sheet_name='d20_insemrna_cds_group_sumdown',index = True)
# 
# writer.close()

# %%
# writer = pd.ExcelWriter(r'H:\d6周海倩+2022020702&2022091526+Supplementary+Analysis+b20231013\d1d6d20的mrna中出现的peak的up down分组\d1d6d20的mrna中出现的peak的up down分组_update20240130.xlsx')
# 
# d1_up_isinse_isinmrna.to_excel(writer,sheet_name='d1_up_isinse_isinmrna',index=False)
# 
# d1_down_isinse_isinmrna.to_excel(writer,sheet_name='d1_down_isinse_isinmrna',index=False)
# 
# d6_up_isinse_isinmrna.to_excel(writer,sheet_name='d6_up_isinse_isinmrna',index=False)
# 
# d6_down_isinse_isinmrna.to_excel(writer,sheet_name='d6_down_isinse_isinmrna',index=False)
# 
# d20_up_isinse_isinmrna.to_excel(writer,sheet_name='d20_up_isinse_isinmrna',index=False)
# 
# d20_down_isinse_isinmrna.to_excel(writer,sheet_name='d20_down_isinse_isinmrna',index=False)
# 
# writer.close()
